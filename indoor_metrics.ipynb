# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\SunnyVanderwall\OneDrive - Medieinstitutet i Sverige\Documents\time_series_summer_ml\simulated_indoor_climate.csv')

# %%
df.columns
# Out:
# Index(['Date', 'Time (UTC)', 'Datetime', 'Air Temperature',
#        'Air Temperature Quality', 'Precipitation Amount',
#        'Precipitation Amount Quality', 'Wind Direction',
#        'Wind Direction Quality', 'Wind Speed', 'Wind Speed Quality',
#        'Relative Humidity', 'Relative Humidity Quality',
#        'Global Irradiance (Swedish stations) W/m²',
#        'Global Irradiance Quality', 'Sunshine Duration (s)',
#        'Sunshine Duration Quality', 'Hour sin', 'Hour cos', 'Day of Year sin',
#        'Day of Year cos', 'Month sin', 'Month cos', 'Indoor_Temperature',
#        'Indoor_Humidity'],
#       dtype='object')

# %%
df['Indoor_Temperature'].value_counts()
# Out:
# Indoor_Temperature
# 30.000000    33981
# 15.000000    14017
# 23.255344       11
# 19.851089        9
# 21.553216        8
#              ...
# 28.040634        1
# 17.446377        1
# 23.568660        1
# 15.295484        1
# 20.200448        1
# Name: count, Length: 142, dtype: int64
